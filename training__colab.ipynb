# %% [markdown]
# <a href="https://colab.research.google.com/github/chandrakanta-chaudhury/Image-video-analysis/blob/master/training__colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %%
# !ls
# Out:
# drive  sample_data

# %%
os.chdir("/drive/My Drive")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-2c0a2bebbed5> in <module>()
# ----> 1 os.chdir("/drive/My Drive")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/drive/My Drive'

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.chdir("/content/drive/My Drive")

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive'

# %%
# !ls
# Out:
#  119065acf183681ed4fe6c94cea12c29163f66184d69042146da0b90467f9a65.pdf
#  Algorithimca
#  BayesianStatisticsandMarketing_byRossiand_Allenby.pdf
# 'Bolstad_2007_Introduction to Bayesian Statistics.pdf'
#  certificates.tar.gz
#  cfog_payslip.tar.gz
# 'chandrakanta Chaudhury.pdf'
# 'CHAUDHURY CHANDRAKANTA.pdf'
# 'Colab Notebooks'
# 'Deloitte_Offer (1).pdf'
#  Deloitte_Offer.pdf
#  Deloitte_Offer.zip
# 'epayslip (1).pdf'
#  epayslip.pdf
#  frozen_inference_graph.pb
#  icici.PNG
#  img084.pdf
#  img771.jpg
# "Jason's Machine Learning 101.gslides"
#  masan_2.mp4
# 'ML book-dj.tar.gz'
#  pascal_label_map.pbtxt
#  payslip-april-2019.pdf
#  payslip_august_2019.pdf
#  payslip_july_2019.pdf
#  payslip_may-2019.pdf
#  payslip-may-2019.pdf
#  payslip_october_2019.pdf
#  payslip_september-2019.pdf
#  pyton.pdf
#  Relieving_Letter.pdf
#  research.tar.gz
#  springboard_getting_data_science.pdf
#  untitled0.py

# %%
# !tar -xvf research.tar.gz
# Out:
# research/steve/config/experiments/goodruns/swimmer/mve_tdk2.json
# research/object_detection/g3doc/img/dataset_explorer.png
# research/syntaxnet/dragnn/core/test/generic.cc
# research/swivel/glove_to_shards.py
# research/lexnet_nc/learn_classifier.py
# research/object_detection/predictors/rfcn_box_predictor.py
# research/compression/entropy_coder/dataset/
# research/object_detection/builders/__pycache__/box_predictor_builder.cpython-36.pyc
# research/object_detection/models/__pycache__/faster_rcnn_pnas_feature_extractor.cpython-36.pyc
# research/rebar/README.md
# research/slim/nets/mobilenet/__pycache__/mobilenet.cpython-36.pyc
# research/object_detection/core/__pycache__/__init__.cpython-36.pyc
# research/skip_thoughts/skip_thoughts/evaluate.py
# research/object_detection/builders/__pycache__/dataset_builder.cpython-36.pyc
# research/object_detection/builders/__pycache__/hyperparams_builder.cpython-36.pyc
# ...

# %%
os.chdir("/content/drive/My Drive/research")

# %%
# !ls
# Out:
# a3c_blogpost			  lm_commonsense
# adversarial_crypto		  lstm_object_detection
# adversarial_logit_pairing	  marco
# adversarial_text		  maskgan
# adv_imagenet_models		  morph_net
# astronet			  namignizer
# attention_ocr			  neural_gpu
# audioset			  neural_programmer
# autoaugment			  next_frame_prediction
# autoencoder			  nst_blogpost
# brain_coder			  object_detection
# cognitive_mapping_and_planning	  pcl_rl
# cognitive_planning		  ptn
# compression			  qa_kg
# cvt_text			  README.md
# deep_contextual_bandits		  real_nvp
# deeplab				  rebar
# deep_speech			  resnet
# delf				  sentiment_analysis
# differential_privacy		  seq2species
# domain_adaptation		  setup.py
# efficient-hrl			  skip_thoughts
# feelvos				  slim
# fivo				  steve
# gan				  street
# global_objectives		  struct2depth
# im2txt				  swivel
# inception			  syntaxnet
# keypointnet			  tcn
# learned_optimizer		  tensorrt
# learning_to_remember_rare_events  textsum
# learning_unsupervised_learning	  transformer
# ...

# %%
os.chdir("/content/drive/My Drive/research/object_detection")

# %%
# !ls
# Out:
# anchor_generators		     meta_architectures
# box_coders			     metrics
# builders			     model_hparams.py
# CONTRIBUTING.md			     model_lib.py
# core				     model_lib_test.py
# data				     model_lib_v2.py
# data_decoders			     model_lib_v2_test.py
# dataset_tools			     model_main.py
# dockerfiles			     models
# eval_util.py			     model_tpu_main.py
# eval_util_test.py		     object_detection_tutorial.ipynb
# exporter.py			     predictors
# exporter_test.py		     protos
# export_inference_graph.py	     __pycache__
# export_tflite_ssd_graph_lib.py	     README.md
# export_tflite_ssd_graph_lib_test.py  samples
# export_tflite_ssd_graph.py	     ssdlite_mobilenet_v2_coco_2018_05_09
# g3doc				     test_ckpt
# inference			     test_data
# __init__.py			     test_images
# inputs.py			     tpu_exporters
# inputs_test.py			     train.py
# legacy				     utils
# matchers

# %%
# !python train.py
# Out:
# Traceback (most recent call last):
#   File "train.py", line 49, in <module>
#     from object_detection.builders import dataset_builder
# ModuleNotFoundError: No module named 'object_detection'

# %%
export PYTHONPATH=$PYTHONPATH:`pwd`:`pwd`/slim
# Out:
#   File "<ipython-input-17-75480d81aba2>", line 1
#     export PYTHONPATH=$PYTHONPATH:`pwd`:`pwd`/slim
#                     ^
# SyntaxError: invalid syntax

# %%
# !export PYTHONPATH=$PYTHONPATH:`pwd`:`pwd`/slim

# %%
# !python3 train.py --logtostderr --train_dir=data/ --pipeline_config_path=ssdlite_mobilenet_v2_coco_2018_05_09/ssdlite_mobilenet_v2_coco.config
# Out:
# Traceback (most recent call last):
#   File "train.py", line 49, in <module>
#     from object_detection.builders import dataset_builder
# ModuleNotFoundError: No module named 'object_detection'

# %%
os.chdir("/content/drive/My Drive/research")

# %%
# !export PYTHONPATH=$PYTHONPATH:`pwd`:`pwd`/slim

# %%
os.chdir("/content/drive/My Drive/research/object_detection")

# %%
# !python3 train.py --logtostderr --train_dir=data/ --pipeline_config_path=ssdlite_mobilenet_v2_coco_2018_05_09/ssdlite_mobilenet_v2_coco.config
# Out:
# Traceback (most recent call last):
#   File "train.py", line 49, in <module>
#     from object_detection.builders import dataset_builder
# ModuleNotFoundError: No module named 'object_detection'

# %%
# !export PYTHONPATH=$PYTHONPATH:`/content/drive/My Drive/research`:`/content/drive/My Drive/research`/slim
# Out:
# /bin/bash: /content/drive/My: No such file or directory
# /bin/bash: /content/drive/My: No such file or directory

# %%
# !export PYTHONPATH=$PYTHONPATH:`/content/drive/My Drive/research`:`/content/drive/My Drive/research`/slim
# Out:
# /bin/bash: /content/drive/My: No such file or directory
# /bin/bash: /content/drive/My: No such file or directory

# %%
! echo $PYTHONPATH
# Out:
# /env/python

# %%
os.environ['PYTHONPATH'] += ":/content/gdrive/My Drive/research/slim"

# %%
 ! echo $PYTHONPATH
# Out:
# /env/python:/content/gdrive/My Drive/research:/content/gdrive/My Drive/research/slim

# %%
os.chdir("/content/drive/My Drive/research/object_detection")

# %%
# !python3 train.py --logtostderr --train_dir=data/ --pipeline_config_path=ssdlite_mobilenet_v2_coco_2018_05_09/ssdlite_mobilenet_v2_coco.config
# Out:
# Traceback (most recent call last):
#   File "train.py", line 49, in <module>
#     from object_detection.builders import dataset_builder
# ModuleNotFoundError: No module named 'object_detection'

# %%
# %set_env PYTHONPATH=/content/models/research:/content/models/research/slim
# Out:
# env: PYTHONPATH=/content/models/research:/content/models/research/slim

# %%
# !python3 train.py --logtostderr --train_dir=data/ --pipeline_config_path=ssdlite_mobilenet_v2_coco_2018_05_09/ssdlite_mobilenet_v2_coco.config
# Out:
# Traceback (most recent call last):
#   File "train.py", line 49, in <module>
#     from object_detection.builders import dataset_builder
# ModuleNotFoundError: No module named 'object_detection'

# %%
#!protoc object_detection/protos/*.proto — python_out=.
# Out:
# Missing output directives.

# %%
#!python object_detection/builders/model_builder_test.py
# Out:
# python3: can't open file 'object_detection/builders/model_builder_test.py': [Errno 2] No such file or directory

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/research/object_detection'

# %%
os.environ['PYTHONPATH'] += ":/content/drive/My Drive/research/slim"

# %%
# !python3 object_detection/train.py --logtostderr --train_dir=object_detection/data/ --pipeline_config_path=object_detection/ssdlite_mobilenet_v2_coco_2018_05_09/ssdlite_mobilenet_v2_coco.config
# Out:
# python3: can't open file 'object_detection/train.py': [Errno 2] No such file or directory

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/research/object_detection'

# %%
os.chdir("/content/drive/My Drive/research")

# %%
# !python3 object_detection/train.py --logtostderr --train_dir=object_detection/data/ --pipeline_config_path=object_detection/ssdlite_mobilenet_v2_coco_2018_05_09/ssdlite_mobilenet_v2_coco.config
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/research/slim/nets/inception_resnet_v2.py:373: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/research/slim/nets/mobilenet/mobilenet.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From object_detection/train.py:55: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# ...

# %%
os.environ['PYTHONPATH'] += ":/content/drive/My Drive/research/slim"

# %%
# %set_env PYTHONPATH=/content/drive/My Drive/research:/content/drive/My Drive/research/slim
# Out:
# env: PYTHONPATH=/content/drive/My Drive/research:/content/drive/My Drive/research/slim

# %%
# !python3 object_detection/train.py --logtostderr --train_dir=object_detection/data/ --pipeline_config_path=object_detection/ssdlite_mobilenet_v2_coco_2018_05_09/ssdlite_mobilenet_v2_coco.config
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/research/slim/nets/inception_resnet_v2.py:373: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/research/slim/nets/mobilenet/mobilenet.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From object_detection/train.py:55: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# ...

# %%
# !zip -r ./content/file.zip ./content/drive/My Drive/research/object_detection/data
# Out:
# 	zip warning: name not matched: ./content/drive/My
# 	zip warning: name not matched: Drive/research/object_detection/data
#
# zip error: Nothing to do! (try: zip -r ./content/file.zip . -i ./content/drive/My Drive/research/object_detection/data)

# %%
from google.colab import files

# %%
# !zip -r /content/file.zip '/content/drive/My Drive/research/object_detection/data'
# Out:
#   adding: content/drive/My Drive/research/object_detection/data/ (stored 0%)
#   adding: content/drive/My Drive/research/object_detection/data/pascal_label_map.pbtxt (stored 0%)
#   adding: content/drive/My Drive/research/object_detection/data/mscoco_complete_label_map.pbtxt (deflated 79%)
#   adding: content/drive/My Drive/research/object_detection/data/model.ckpt-0.meta (deflated 93%)
#   adding: content/drive/My Drive/research/object_detection/data/test.record (deflated 0%)
#   adding: content/drive/My Drive/research/object_detection/data/model.ckpt-0.index (deflated 77%)
#   adding: content/drive/My Drive/research/object_detection/data/face_label_map.pbtxt (deflated 21%)
#   adding: content/drive/My Drive/research/object_detection/data/ava_label_map_v2.1.pbtxt (deflated 74%)
#   adding: content/drive/My Drive/research/object_detection/data/oid_v4_label_map.pbtxt (deflated 79%)
# ...

# %%
files.download('/content/file.zip')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-77-451b59c06e33> in <module>()
# ----> 1 files.download('/content/file.zip')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     176       'port': port,
#     177       'path': _os.path.abspath(filename),
# --> 178       'name': _os.path.basename(filename),
#     179   })
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      99     reply = _read_next_input_message()
#     100     if reply == _NOT_READY or not isinstance(reply, dict):
# --> 101       time.sleep(0.025)
# ...
